# %%
caracteres_resumen = input('Introduce un texto')
#caracteres_antecedentes = input('Introduce un texto')
conta = 0
for i in caracteres_resumen:
    if i ==' ':
        conta += 0
    else: conta += 1


print(f'El resumen tiene un total de: {conta} caracteres')
# Out:
# El resumen tiene un total de: 3 caracteres
